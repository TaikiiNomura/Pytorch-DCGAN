# %%
# !git clone https://github.com/TaikiiNomura/Pytorch-DCGAN.git
# Out:
# Cloning into 'Pytorch-DCGAN'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 49 (delta 16), reused 43 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 21.38 KiB | 5.34 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd Pytorch-DCGAN/notebooks
# Out:
# /content/Pytorch-DCGAN/notebooks

# %%
# %run train_dcgan.ipynb
# Out:
# Cloning into 'Pytorch-DCGAN'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 49 (delta 16), reused 43 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 21.38 KiB | 2.38 MiB/s, done.
# Resolving deltas: 100% (16/16), done.
# Current directory: /content/Pytorch-DCGAN/notebooks/Pytorch-DCGAN
# Using device: cuda:0
#
# Configuration:
#   Batch Size: 128
#   Image Size: 32
#   Num Epochs: 50
#   Learning Rate: 0.0002
#   Latent Dim (nz): 100
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 13.4MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 207kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.94MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 14.4MB/s]
# Dataset loaded: 469 batches
# Generator:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 256, kernel_size=(4, 4), stride=(1, 1), bias=False)
# ...
